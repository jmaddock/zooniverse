# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')

import requests
import json
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# set the API endpoint
base_url = r'https://panoptes.zooniverse.org/api/projects'
# set necessary headers for zooniverse API
headers = {
    'Accept':'application/vnd.api+json; version=1',
    'Content-Type':'application/json'
}
params = {}
api_result_df = pd.DataFrame()
while True:
    # send and recieve HTTP request to API endpoint
    r = requests.get(base_url,
                    params=params,
                    headers=headers)
    # convert the result to JSON
    api_result = r.json()
    # iterate through each project in a page of API results
    for project in api_result['projects']:
        pp.pprint(project['tags'])
    
    # if there is another page of search results, add that href to the next query
    # else return the API result
    if api_result['meta']['projects']['next_href']:
        params['page'] = api_result['meta']['projects']['next_href'].split('=')[-1]
        print(api_result['meta']['projects']['next_href'])
    else:
        break
        
# convert the project ID from a string to a numeric field
#api_result_df['panoptes_project_id'] = pd.to_numeric(api_result_df['panoptes_project_id'])
# create a panoptes_api field
#api_result_df['panoptes_api'] = 1
# Out:
# []
# [   'medicine',
#     'climate',
#     'diabetes,water pollution,endocrine disrupters,farmer',
#     'nature',
#     'biology']
# [' wildlife', 'nature', 'biology']
# ['nature', 'biology']
# ['history']
# [' plants', 'nature', 'biology']
# ['astronomy']
# ['language', 'transcription', 'history', 'social science']
# ['geology, geophysics, earthquakes', 'nature']
# [   'wildlife biology',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     ' camera traps',
#     'africa',
#     'mammals',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     ' biology',
#     'nature',
#     'biology',
#     ' lion',
#     ' conservation']
# []
# [   'fossils',
#     ' fossilfinder',
#     ' evolution',
#     'palaeoanthropology',
#     ' paleoanthropology',
#     'history',
#     'nature',
#     'social science',
#     'biology',
#     'archaeology']
# [   'archives',
#     'canada',
#     'quebec',
#     'photograph',
#     'history',
#     'collections',
#     'silver',
#     'mcgill',
#     'arts']
# []
# ['language', 'video', 'audio', 'history']
# ['playstation', 'xbox']
# ['antarctica', 'seabird', 'penguins', 'camera-trap']
# [   'ww2',
#     'world war two',
#     'military',
#     'race',
#     'history',
#     'war',
#     'wwii',
#     'social science']
# []
# ['ocean', 'sea', 'fish', 'adriatic', 'venice', 'webcam', 'nature', 'biology']
# /projects?page=2
# ['language', 'literature', 'history', 'arts', 'social science']
# ['ancient-lives']
# ['i', 'a', 'nature', 'biology']
# [   'wildlife biology',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     ' camera traps',
#     'africa',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap',
#     ' conservation']
# ['space ', 'mars ', 'astronomy', 'planetary science']
# [   'conservation',
#     'wildlife biology',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     'africa',
#     'camera traps',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap']
# [   'birds',
#     'wildlife biology',
#     'giraffes',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     'elephants',
#     'africa',
#     'mammals',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'camera-trap',
#     'nature',
#     'biology',
#     ' lion',
#     'camera',
#     ' conservation']
# []
# ['history', 'social science']
# ['medicine', 'nature', 'biology']
# ['cameratrap', 'amazon', 'jaguar ', 'south america', 'nature', 'biology']
# ['astronomy', 'clusters', ' star clusters']
# [   'birds',
#     'insects',
#     'ecology ',
#     'mammals',
#     'natural history',
#     'bryophytes',
#     'biology',
#     'plants']
# ['antarctica', ' seal', ' ross sea', 'nature', 'biology']
# ['climate']
# [   'weather',
#     'rainfall',
#     'climate',
#     'atmosphere, ',
#     'meteorology',
#     'temperature',
#     ' history',
#     'nature']
# []
# ['climate', 'ecology ', 'nature']
# []
# ['climate', 'nature', 'biology']
# /projects?page=3
# [   'seagrass',
#     ' underwater',
#     ' national marine aquarium',
#     ' community seagrass initative',
#     ' divers',
#     ' baited underwater camera']
# []
# ['nature', 'ecology ', 'animals', 'biology']
# ['biology', 'entomology', 'label transcription', 'taxonomic determination']
# ['phenology', 'ecology ', 'transcription', ' climate change']
# ['astronomy', 'physics']
# []
# [   'nature',
#     'birds',
#     'ecology ',
#     ' conservation',
#     'wildlife',
#     'camera',
#     'wildlife biology',
#     'mammal',
#     ' lion',
#     'camera-trap',
#     'elephants',
#     'giraffes',
#     'biology',
#     'africa',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'mammals',
#     'reptiles']
# [   'physics',
#     'biology',
#     'history',
#     'microscopy, pms, social history',
#     ', london, herbalist, pharmacy.']
# ['nature', 'biology']
# ['nature', 'climate', 'weather']
# ['medicine', 'arts', 'social science']
# ['medicine', 'biology']
# [   'birds need help',
#     'nature',
#     'birds ',
#     'wildlife',
#     'biology',
#     'birds, winter, ']
# []
# [   'nature',
#     'ocean',
#     'identify',
#     'biology',
#     'marine',
#     ' photo',
#     'photograph',
#     'sea',
#     'fish',
#     ' marine biology',
#     'shark',
#     'elasmobranch',
#     'elasmo',
#     'drone',
#     'marine ecology',
#     'photos']
# [   'nature',
#     'forest',
#     'rainforest',
#     'endangered',
#     'animals',
#     'elephants',
#     'biology',
#     'africa',
#     'camera trap',
#     'buffalo',
#     ' tropical forest',
#     'gorilla',
#     'chimpanzee ',
#     'tropics',
#     'central africa',
#     'primate',
#     'ape']
# ['astronomy', 'stars', 'planets']
# [   'nature',
#     'animals',
#     'camera',
#     'cameratrap',
#     ' mountains',
#     ' colorado',
#     ' vail pass',
#     ' corridors',
#     ' wildlife corridors',
#     ' lynx',
#     ' i-70',
#     ' highways',
#     ' roads',
#     ' ecosystems',
#     ' wildlife overpass',
#     ' wildlife bridge',
#     'moose',
#     'photo',
#     'photograph',
#     ' elk',
#     ' deer']
# ['nature', 'history', 'literature', 'arts']
# /projects?page=4
# ['astronomy', ' galaxies']
# ['medicine', 'annotation', 'segmentation', 'biology']
# [   'animals',
#     'climate change',
#     'maps',
#     'biodiversity',
#     'museum',
#     'climate',
#     'transcription',
#     'nature',
#     'biology',
#     'plants']
# []
# ['rocket sience', 'astronomy', 'physics']
# []
# [   ' culture',
#     'drawing',
#     'painting',
#     'history',
#     'art',
#     'collections',
#     'accessibility ',
#     'disability ',
#     'arts']
# ['i', 'i', 'animal behavior', 'a', 'a', 'nature', 'biology']
# ['climate']
# ['climate', 'wildlife', 'nature', 'biology']
# ['b', 'w', 's', 'f', 'f', 'a', 'o', 'biology']
# ['nature']
# [   'p',
#     'climate',
#     's',
#     'i',
#     'i',
#     'c',
#     'a',
#     'a',
#     'o',
#     'o',
#     'nature',
#     'biology',
#     'l']
# [' history', 'arts', 'archaeology']
# []
# [   'seasons',
#     'leaves',
#     'trees',
#     'grass',
#     'phenology',
#     'winter',
#     'summer',
#     'fall',
#     'spring',
#     'autumn',
#     ' ecology',
#     'climate',
#     ' biology',
#     'nature',
#     'biology',
#     'plants']
# []
# []
# ['test', 'history']
# ['astronomy', 'astronomy,galaxies,hubble']
# /projects?page=5
# [   'astronomy',
#     ' galaxies',
#     'galaxy',
#     'computer science',
#     'machine learning',
#     'computer vision']
# []
# [   'intangible cultural heritage',
#     'traditional music',
#     'musical instruments',
#     'tajikistan',
#     'arts',
#     'cultural heritage']
# [   'human-nature conflict',
#     'bees',
#     'human-wildlife coexistence',
#     'elephants',
#     'wildlife',
#     'nature',
#     'social science',
#     'biology']
# []
# ['climate', 'n', 'h', 'a', 'o', 'r', 'nature', 'l']
# ['mars ', 'classification']
# []
# ['modeling', 'ecology ', ' biology']
# ['astronomy']
# ['humanitarian', ' disaster relief', 'climate', 'disaster response', 'nature']
# ['arts']
# []
# ['cinnabar', ' dominica geology']
# ['astronomy', 's']
# [   'birds need help',
#     'birds ',
#     ' sea birds',
#     'science',
#     'citizen science',
#     ' bird']
# [   'deer',
#     'snapshot',
#     'ecology ',
#     ' camera traps',
#     'mammals',
#     'veluwe',
#     'hoge veluwe',
#     'wildlife',
#     'nature']
# []
# ['language', 'history', 'social science']
# ['history', 'nature', 'social science']
# /projects?page=6
# ['cameratrap', 'wildlife', 'nature', 'biology']
# ['climate', 'nature', 'biology']
# ['global warming', 'antarctica', ' snow', 'ice', 'coldness']
# ['health', 'medicine', 'technology', 'datascience', 'climate', 'meteorology']
# ['physics']
# ['ww1', 'ymca', 'history', 'social science']
# [   'rainforest',
#     ' aerial',
#     'borneo',
#     'orangutan',
#     'photography',
#     'malaysia',
#     'primate',
#     'drone',
#     'nature',
#     'social science',
#     'biology',
#     ' conservation']
# []
# ['astronomy', 'classify', 'milky way', 'physics']
# ['astronomy', ' astrophysics', 'physics', 'planets']
# ['climate', 'nature', 'social science']
# ['cam']
# []
# ['citizen science', 'classify', 'satellite imagery', 'africa', 'social science']
# [' evolution', ' climate change', 'climate', 'nature', 'biology']
# ['astronomy', 'stars', 'variable stars', 'physics', 'superwasp']
# ['astronomy']
# ['medicine', 'nature', 'biology']
# ['logo', ' pair', 'favorite', 'choice']
# []
# /projects?page=7
# ['climate change, citizen science', 'biology']
# [' climate change', 'climate', ' tropical forest', 'biology', ' conservation']
# []
# []
# [   'agriculture',
#     'counting',
#     'machinelearning',
#     'classification',
#     'machine learning',
#     'nature',
#     'biology',
#     'phenotyping',
#     'genomics',
#     'plants']
# [   'c',
#     'a',
#     'a',
#     'a',
#     'a',
#     'o',
#     'e',
#     'e',
#     'r',
#     'nature',
#     'social science',
#     'biology',
#     'd',
#     'l']
# [   'wildlife biology',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     ' camera traps',
#     'africa',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap',
#     ' conservation']
# ['movies', 'literature']
# [   'birds',
#     'wildlife biology',
#     'giraffes',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     'elephants',
#     'africa',
#     'mammals',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'camera-trap',
#     'nature',
#     'biology',
#     ' lion',
#     'camera',
#     ' conservation']
# [' marine mammal', 'manatee', 'nature', 'biology']
# [   'wildlife biology',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     'africa',
#     'camera traps',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap',
#     ' conservation']
# [   'civil war',
#     'african-american history',
#     'black history',
#     'american civil war',
#     'history',
#     ' genealogy',
#     ' history',
#     'arts',
#     'social science']
# [   'medicine',
#     ' pollution',
#     'audio',
#     'climate',
#     'soundscape',
#     'smart city',
#     'sound',
#     'social science',
#     'urban']
# ['bugs', 'butterflies', 'history', 'nature', 'plants']
# [   'calgary ',
#     'miistakis',
#     'calgary captured',
#     'calgary parks',
#     'urban conservation',
#     'wildlife ',
#     'nature',
#     'biology']
# [   'medicine',
#     'annotation',
#     'proteins; cells ',
#     'virus',
#     'segmentation',
#     'biology']
# [   'predators, endangered shore birds, central platte river, nebraska, '
#     'sandpit ',
#     'nature',
#     'biology']
# ['medicine', ' health', 'social behavior', 'nature', 'biology']
# [   'w',
#     'm',
#     'm',
#     't',
#     'i',
#     'i',
#     'i',
#     'i',
#     'i',
#     'i',
#     'c',
#     'c',
#     'c',
#     'a',
#     'a',
#     'a',
#     'a',
#     'a',
#     'a',
#     'o',
#     'e',
#     'nature',
#     'biology',
#     'l']
# [   'invasive species',
#     ' marine biology',
#     'marine',
#     'climate',
#     'invertabrate',
#     'coastal',
#     'nature',
#     'biology']
# /projects?page=8
# [   'wolf ',
#     'prey',
#     'ecology ',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'camera trapping',
#     ' biology',
#     'animal behavior',
#     'trophic cascade',
#     'herbivore',
#     'predator ',
#     'nature',
#     'biology',
#     'camera trap']
# ['astronomy', ' modelling', ' astrophysics', 'galaxy', 'physics']
# ['biodiversity', 'africa', 'nature', 'biology', ' conservation']
# ['great salt lake, utah ', 'pelicans', 'gunnison island']
# [   ' toledo zoo',
#     'cameratrap',
#     ' camera traps',
#     'wildlife',
#     'camera-trap',
#     ' biology',
#     'a',
#     'camera']
# ['nature', 'biology']
# ['language', 'machine learning', 'artificial intelligence']
# ['physics']
# ['social science']
# [   'marine science',
#     'physics',
#     'spectroscopy',
#     'computer vision',
#     'animal behavior',
#     'nature',
#     'biology']
# [   'agriculture',
#     'phenology',
#     ' horticulture',
#     'machine learning',
#     'agronomy',
#     'university of nebraska lincoln',
#     ' genealogy',
#     'schnablelab',
#     'innovation campus',
#     'unl',
#     'nature']
# [   'measuring',
#     ' butterfly',
#     ' climate',
#     'evolution',
#     ' nature',
#     ' wildlife',
#     ' insects']
# [   ' environment',
#     'morphometrics',
#     'ecology ',
#     ' animal population',
#     'fish',
#     'nature',
#     'biology']
# ['astronomy']
# [   'ground-truth image dataset',
#     'digital humanities',
#     'computer history',
#     'journalism history']
# ['geography', 'gis', 'social science']
# [   'galaxies',
#     'pulsars',
#     'astronomy',
#     ' black holes',
#     'quasars',
#     '#stars',
#     'physics',
#     '#planets',
#     'exoplanets',
#     'social science',
#     'universe']
# []
# ['h', 'i', 'a', 'nature', 'biology']
# []
# /projects?page=9
# ['invasive alien species', 'biology']
# ['birds', 'manakins', 'animal behavior', 'biology']
# [   'science',
#     'modeling',
#     ' science',
#     'proteins',
#     'structural biology',
#     ' biology',
#     'biology']
# []
# []
# ['astronomy', 'physics', 'planets, exoplanets']
# []
# [   'birds',
#     'video',
#     'behavior',
#     'ornithology',
#     'ecology ',
#     'animal',
#     'bird',
#     'animal behavior',
#     'nature',
#     'biology']
# ['medicine', ' biology']
# [   'mars ',
#     'astronomy',
#     'physics',
#     'planetary science',
#     'features',
#     'orbital imagery',
#     'orbiter',
#     'change detection',
#     'landforms',
#     'nature']
# [   'wildlife biology',
#     ' wildlife',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     ' camera traps',
#     'africa',
#     'reptiles',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap',
#     ' conservation']
# []
# [' ecosystems', 'physics', 'ecology ', 'nature', 'renewable energy ']
# []
# ['medicine']
# [' language', 'metaphor', 'simili', 'idiom']
# []
# ['climate', 'history', 'l']
# []
# [' botany', 'ferns', 'nature', 'biology', 'plants']
# /projects?page=10
# ['geography', 'social science']
# ['astronomy']
# ['biology']
# ['tag']
# ['galaxies']
# ['nature']
# []
# []
# ['space ']
# ['mapping', 'lviv', 'history']
# []
# []
# []
# []
# ['astronomy', 'physics']
# [   'medicine',
#     'chicago',
#     'physics',
#     'history',
#     'exercise',
#     'running',
#     'social science',
#     'biology']
# ['galaxies', 'astronomy', ' astrophysics', 'physics', 'spectroscopy']
# [   'morphology',
#     'streams',
#     'aquatic ecology',
#     'climate',
#     'mussels',
#     'shell',
#     'milwaukee public museum',
#     'shape',
#     'measure',
#     'nature',
#     'biology']
# ['biology']
# ['astronomy', 'the sun']
# /projects?page=11
# []
# ['galaxies', 'science', 'citizen science', 'astronomy']
# ['politics', 'language', 'law', 'history', 'social science']
# ['cheetah', 'namibia  ', 'wildlife', 'nature', 'biology']
# ['mammals', 'nebraska', 'skunks', 'nature', 'biology']
# []
# [   ' literature',
#     ' translation',
#     'language',
#     'literature',
#     'russian novel ',
#     'fairytale']
# ['galaxies', 'astronomy', 'radio', 'physics']
# ['poaching', 'astro-ecology', 'drones', 'thermal cameras', 'nature']
# ['space ', ' solar system', 'astronomy', 'asteroids', 'rock']
# []
# ['i', 'history']
# []
# []
# []
# []
# [   'b',
#     'n',
#     'i',
#     'i',
#     'u',
#     'a',
#     'a',
#     'o',
#     'r',
#     'r',
#     'nature',
#     'biology',
#     'd',
#     'd',
#     'd']
# []
# []
# ['astronomy', 'asteroids', 'planetary science']
# /projects?page=12
# []
# []
# ['astronomy']
# ['astronomy', 'climate']
# ['duck', 'nature']
# []
# []
# ['ancient-lives']
# ['social science']
# []
# ['astronomy']
# []
# ['nature', 'biology']
# []
# ['animals', 'behavior', 'ornithology', 'bird', 'biology']
# []
# ['climate', 'nature']
# []
# ['teste', 'physics', 'nature']
# ['language', 'xd', 'arts', 'social science']
# /projects?page=13
# []
# ['biology']
# []
# []
# ['biology']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['biology']
# []
# []
# ['cheese']
# []
# []
# /projects?page=14
# []
# []
# ['law', 'literature', 'history']
# []
# []
# []
# ['bvi']
# [   'language',
#     '#psychology #philosophy #linguistics',
#     'arts',
#     'nature',
#     'social science']
# []
# [' botany', 'nature', 'biology']
# []
# ['nature']
# []
# []
# []
# ['astronomy', 'astronomy, spirals']
# ['insects', 'entomology', 'transcription', 'collections']
# []
# []
# [   ' solar system',
#     ' fun',
#     ' banter',
#     ' amusing',
#     ' destroy',
#     ' the world',
#     ' death',
#     ' kepler 7898797889bfg',
#     'planets',
#     ' animals']
# /projects?page=15
# ['galaxies']
# []
# []
# []
# []
# []
# []
# ['astronomy', 'climate']
# []
# ['computer history', 'climate', 'history']
# []
# []
# []
# []
# []
# []
# []
# []
# ['machine learning']
# []
# /projects?page=16
# ['nature', 'biology']
# ['eo', 'waterholes']
# ['cat', 'biology']
# ['astronomy', 'physics']
# []
# [   ' pollution',
#     'green',
#     'global warming',
#     'make green',
#     'green planet',
#     'nature']
# []
# []
# []
# []
# []
# []
# []
# ['horse']
# ['astronomy', 'physics']
# ['archives', ' language', ' translation', ' transcription', 'documents']
# [' culture', 'architecture ', 'astronomy', 'history', 'social science']
# []
# []
# []
# /projects?page=17
# ['language', 'literature', 'history']
# [' species', ' habitat', 'wildlife', 'nature', 'biology']
# ['observations', 'home', 'discussion', 'profile']
# []
# ['astronomy', 'arts']
# []
# ['biolo']
# ['nature']
# []
# []
# []
# []
# ['astronomy', 'rock', ' mars', ' curiosity']
# [   'medicine',
#     'cancer ',
#     'hpv',
#     'vaccination',
#     'vaccine',
#     'public health',
#     'social media',
#     'social science',
#     'biology']
# []
# ['photography', 'history', 'arts', 'urban']
# []
# ['nature']
# []
# ['astronomy']
# /projects?page=18
# []
# [' botany', 'taxonomy', 'nature', 'biology']
# ['galaxies', 'stars']
# []
# []
# ['astronomy']
# []
# ['astronomy']
# ['astronomy', 'physics']
# []
# ['astronomy']
# []
# []
# []
# []
# []
# [   'birds',
#     ' evolution',
#     'museum',
#     'ornithology',
#     'zoology, birds',
#     'macroevolution',
#     'collections',
#     'zoology',
#     'natural history',
#     'plumage',
#     'colour',
#     'ultraviolet',
#     'bird',
#     'nature',
#     'biology']
# []
# []
# []
# /projects?page=19
# ['literature', 'thomas hardy', 'history']
# ['astronomy']
# ['astronomy', 'physics']
# []
# ['australia', 'wildlife', 'camera']
# ['climate']
# []
# ['language', 'literature', 'arts']
# []
# []
# []
# ['ant', 'nature', 'biology']
# []
# ['galaxies', 'astronomy', 'quasars', 'physics']
# []
# [   'ramat hagolan',
#     'רמת הגולן',
#     'טבע',
#     'בעלי חיים',
#     'nature',
#     'social science',
#     'biology']
# ['history']
# []
# ['galaxies', 'astronomy', 'streams', 'galaxy', 'stellar haloes', 'shells']
# ['nature']
# /projects?page=20
# ['astronomy', 'paired-object systems']
# ['astronomy']
# []
# ['history', 'nature', 'biology']
# ['global warming']
# []
# ['grb']
# []
# []
# ['astronomy']
# []
# [   'postkort',
#     ' postcards',
#     ' postcard',
#     ' denmark',
#     'dansk',
#     'danske',
#     ' danish ',
#     ' danmark']
# ['ethical hacking, vapt', 'cyber security']
# ['postcards ', 'language', 'history']
# ['hashtags']
# [   'astronomy',
#     'weather',
#     'physics',
#     'climate',
#     'aurora,',
#     'aurora australis, ',
#     'atmosphere, ',
#     'northern lights,',
#     'aurora borealis, ',
#     'nature']
# []
# []
# []
# ['biology']
# /projects?page=21
# []
# []
# ['astronomy']
# []
# []
# ['pugs']
# ['climate', ' history']
# []
# ['songs', ' personal history', ' local history', ' stories', ' anecdotes']
# []
# ['effort to help', 'homeless animals', 'help to animals']
# ['biology']
# []
# ['mars ', 'astronomy', 'planetary science']
# ['cave', ' pollution', 'animals', 'explore', ' water']
# []
# ['nature']
# []
# ['museums', 'history', 'nature']
# []
# /projects?page=22
# [   'diurnal activity',
#     'antarctica',
#     ' seal',
#     ' mcmurdo sound',
#     ' ross sea',
#     'sea ice',
#     ' marine mammal',
#     'top predator']
# ['nature']
# []
# ['astronomy', 'physics', 'astronomy, cosmology, galaxies']
# [   ' monitoring',
#     'human',
#     'weather',
#     'rainfall',
#     'climate',
#     'temperature',
#     'urban']
# []
# ['bhutanese architecture', 'arts']
# []
# ['boulder county, wildlife camera, critter snap', 'nature', 'biology']
# []
# ['animals', 'ecology ', 'nature']
# []
# []
# []
# [   'stalag 17b',
#     'ww2',
#     'world war two',
#     ' prisoner of war',
#     ' pow',
#     'diary',
#     'alison kay',
#     ' soldier',
#     'family history',
#     'royal british tank regiment',
#     'death march',
#     ' history']
# []
# []
# []
# []
# [   'animals',
#     'wildlife biology',
#     'giraffes',
#     ' habitat',
#     'behavior',
#     ' animal population',
#     'kenya',
#     'africa',
#     'wildlife',
#     'nature',
#     'biology',
#     ' conservation']
# /projects?page=23
# ['biology']
# []
# [   ' denmark',
#     'remote sensing',
#     ' climate',
#     ' human perception',
#     'maps',
#     ' hydrology',
#     ' modelling',
#     'climate',
#     'spatial patterns',
#     'nature']
# []
# []
# []
# []
# ['medicine', 'history']
# []
# ['astronomy']
# []
# []
# ['astronomy', 'nasa', 'apollo', 'mission']
# []
# ['astronomy']
# []
# ['biology']
# ['astronomy', 'stars', ' galaxies', 'supernovae']
# [' music', 'acoustics', 'physics', 'sound']
# []
# /projects?page=24
# []
# ['climate', 'leaves, nature, interresting', 'nature']
# []
# ['literature', 'history']
# []
# ['cat']
# []
# ['cute ', 'social science']
# ['climate', 'nature', 'biology']
# ['jellies', 'biology']
# ['f', 'h', 'i', 'u', 'a', 'a', 'a', 'a', 'a', 'e', 'nature', 'biology']
# ['paired-object systems']
# []
# [   'birds',
#     ' nests',
#     'video',
#     'ornithology',
#     'animal',
#     'bird',
#     ' biology',
#     'animal behavior',
#     'sound',
#     'nature',
#     'biology']
# ['language']
# ['space', 'astronomy', 'comet', 'sky', 'physics', 'nature']
# []
# ['science', 'biology']
# []
# ['galaxies', 'astronomy', 'physics', 'nature']
# /projects?page=25
# ['astronomy', 'nature']
# []
# []
# []
# []
# []
# [   'archives',
#     'language',
#     'documents',
#     'italian ',
#     'transcription',
#     'social network',
#     'history',
#     'arts']
# []
# []
# ['astronomy', 'physics']
# ['astronomy', 'physics']
# ['o', 'e', 'social science', 'l']
# []
# ['#psychology', 'social science']
# ['"><img src=x onerror=alert(2)>', 'biology']
# ['image analysis', 'biology']
# ['asteroids', 'kepler']
# []
# []
# []
# /projects?page=26
# ['climate', 'nature']
# []
# []
# [   'seasons',
#     'leaves',
#     'trees',
#     'grass',
#     'phenology',
#     'winter',
#     'summer',
#     ' spring',
#     'fall',
#     ' autumn',
#     'climate',
#     'ecology ',
#     ' biology',
#     'nature',
#     'biology',
#     'plants']
# ['literature', 'history', 'social science', 'biology']
# []
# []
# []
# [   'animals',
#     'armadillo',
#     ' camera traps',
#     'camera-trap',
#     'camera trap',
#     ' conservation']
# [   ' underwater',
#     ' habitat',
#     'physics',
#     'climate',
#     'geology',
#     'nature',
#     'aquatics']
# []
# ['medicine', 'physics', 'literature', 'history', 'nature', 'biology']
# []
# []
# []
# []
# ['pda']
# []
# [   ' underwater',
#     ' ecosystems',
#     '#video',
#     'aquatic ecology',
#     'ecology ',
#     '#invasive species',
#     ' water',
#     'fish',
#     'great lakes ',
#     'mussels',
#     '#round goby ',
#     '#lakes',
#     ' biology',
#     'nature',
#     'biology',
#     'plants']
# []
# /projects?page=27
# [   ' evolution',
#     'landscape change',
#     'climate',
#     'ecology ',
#     'mammal',
#     'predator ',
#     'nature',
#     'biology',
#     'squirrel',
#     'urban',
#     'hunt ',
#     ' roads']
# []
# ['nature']
# ['nature']
# ['medical history', 'native americans', 'medicine', ' history']
# [   'literature',
#     'history',
#     'arts',
#     'microscopy',
#     'nineteenth century',
#     'periodicals',
#     'illustrations']
# []
# []
# []
# ['black soldier fly ']
# ['stars', 'fun', 'spirul', 'lookout', 'galaxy', 'planets', 'universe']
# []
# ['mammals, fishers, squirrels, carnivores, sierra nevada', 'nature', 'biology']
# []
# [' pollution', 'engineering projects', 'physics']
# [   'medicine',
#     'psychedelics, subjective, drugs, narcotics, ',
#     'social science',
#     'biology']
# []
# []
# ['history', ' history']
# ['physics']
# /projects?page=28
# []
# []
# ['space', 'uranus', 'solar system', 'erath', 'banter', 'tags', 'kepler']
# []
# []
# ['medicine', 'biology']
# []
# ['australia', 'whales', 'marine', ' marine mammal', 'nature', 'biology']
# []
# [   ' educación',
#     ' ciencia',
#     ' tecnología',
#     'aprender',
#     'conocimientos',
#     'científicos',
#     ' tecnológicos',
#     'docentes',
#     ' profesores',
#     ' educadores',
#     'educar']
# []
# []
# ['astronomy']
# []
# []
# ['computer science', 'biology']
# ['biology']
# [   'auto transport fresno ',
#     'auto transport long beach  ',
#     'car transport california ',
#     'auto transport bakersfield  ',
#     'auto transport palm springs\xa0 ']
# ['history']
# ['history', 'arts']
# /projects?page=29
# []
# [   'image tagging',
#     'event tagging',
#     'people tagging',
#     'location tagging',
#     'history']
# [   'jaguar ',
#     'feline',
#     'tapir, endangered, species, identification',
#     'nature',
#     'biology',
#     ' conservation']
# []
# []
# []
# []
# ['medicine']
# []
# [' telescopes', 'astronomy', 'supernovae', 'physics']
# ['space ', 'astronomy', 'milky way', ' astrophysics', 'physics']
# []
# []
# []
# ['cyerbullying', 'bullying', 'social science']
# []
# []
# []
# ['astronomy']
# []
# /projects?page=30
# ['postcards ', 'letters', 'literature', 'history']
# ['biology']
# []
# ['astronomy', 'une vie ailleurs']
# ['love', 'social science']
# []
# []
# ['cats']
# [   'c',
#     'a',
#     'a',
#     'a',
#     'a',
#     'o',
#     'e',
#     'e',
#     'r',
#     'nature',
#     'social science',
#     'biology',
#     'd',
#     'l']
# ['population', 'safety', 'social science']
# ['space ', 'mars ', 'astronomy', 'planetary science', 'geology']
# []
# ['travel, ', 'history', 'arts', 'menus, restaurants, ', 'social science']
# ['nature']
# []
# ['mars ', 'astronomy', 'planets']
# []
# ['biology']
# []
# [   'family history',
#     'age',
#     'census, statistics',
#     'population',
#     'history',
#     ' genealogy',
#     'social science']
# /projects?page=31
# []
# [   'rainforest',
#     'wild animals',
#     'amazon',
#     '"oil pollution" ',
#     'feeding ',
#     'peruvian amazon ',
#     'indigenous people',
#     'camera-trap',
#     'nature',
#     'biology']
# [   'winter',
#     ' health',
#     ' human',
#     'hospital',
#     'pain',
#     ' snow',
#     'ice',
#     ' slush',
#     'car accidents',
#     'slipping',
#     ' falling',
#     'er',
#     'doctors',
#     'nurses',
#     ' surgery',
#     'recovery',
#     'coldness']
# ['language', 'literature', 'history']
# []
# []
# ['astronomy', 'nature']
# []
# [   'truck art, vehicles, trucks, folk art, naive art, india, bangladesh, '
#     'afghanistan, nepal, sri lanka, pakistan, subcontinent, transportation, ',
#     'hindi, bengali, urdu,']
# []
# []
# ['history', 'arts', 'social science', 'archaeology']
# []
# ['nature', 'biology']
# []
# [   'language',
#     'founding fathers',
#     'civil war',
#     ' mount vernon',
#     'signatures',
#     'george washington',
#     'transcription',
#     'history',
#     'writing',
#     ' genealogy']
# []
# []
# []
# []
# /projects?page=32
# ['medicine', 'nature', 'biology']
# []
# []
# ['whales', ' marine biology', 'photography', ' marine mammal', 'biology']
# []
# []
# ['nature']
# []
# ['history', 'social science']
# ['443210098']
# []
# ['social science']
# []
# []
# []
# [   'global warming',
#     'citizen science',
#     ' climate change',
#     'coasts ',
#     ' marine biology',
#     'marine',
#     'climate',
#     ' biology',
#     'uk',
#     'nature',
#     'biology']
# [   'biography ',
#     'new zealand ',
#     'christchurch',
#     'canterbury ',
#     '19th century',
#     '20th century',
#     'history']
# ['nature']
# ['botanics online', 'herbarium', 'flower', 'systematics', 'ecology ']
# ['literature', 'history']
# /projects?page=33
# []
# ['image analysis', 'annotation']
# ['history', 'sports']
# ['memory', 'history', 'anthropology']
# [   'milky way',
#     'nasa',
#     ' proper motion',
#     ' infrared',
#     'galaxy',
#     'variable stars',
#     'spitzer']
# [   'wildlife biology',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     ' camera traps',
#     'africa',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'bird',
#     'camera-trap',
#     'nature',
#     'biology',
#     'camera',
#     'camera trap',
#     ' conservation']
# ['astronomy', 'stars', 'supernovae', 'physics']
# ['galaxies', 'astronomy', 'morphology', 'simulations']
# ['astronomy', 'stars', 'eclipse', 'variable stars', 'machine learning']
# []
# []
# []
# []
# []
# [   'animals',
#     'penguin',
#     'little penguins',
#     'penguins',
#     'zooniverse',
#     'penguins zoo',
#     'phillip island',
#     'wildlife']
# ['arts']
# ['astronomy', 'morphology', ' warp', 'environment', 'interaction', 'galaxy']
# ['wildlife', 'nature', 'biology', 'urban', 'camera trap']
# ['astronomy']
# ['astronomy']
# /projects?page=34
# [   'world war one, first world war, university of sydney, women in war, army '
#     'uniforms, australia']
# ['astronomy']
# []
# []
# []
# []
# ['sustainability fashion ', 'history', 'arts']
# ['astronomy']
# []
# []
# []
# []
# []
# []
# ['scotland', 'wildlife', 'camera trapping', 'nature']
# []
# [   'technology',
#     'image analysis',
#     ' photo',
#     'computervision',
#     'photography',
#     'computer science',
#     'photograph']
# []
# ['astronomy', 'clusters', ' star clusters']
# ['coding']
# /projects?page=35
# []
# [   'space ',
#     'explore',
#     'galaxies',
#     'astronomy',
#     ' evolution',
#     ' black holes',
#     'galaxy',
#     'physics',
#     'universe']
# []
# ['weather', 'satellite imagery', ' thunderstorm', ' severe weather ', 'climate']
# []
# [   ' disease',
#     'virus',
#     'tobacco',
#     'mosaic',
#     'frass',
#     'meal worm',
#     'prevention',
#     'crop',
#     'tomato',
#     'nature',
#     'biology',
#     'plants']
# ['climate', ' history']
# ['m', 'i', 'a', 'e', 'nature', 'biology']
# [   'service management',
#     '[itil foundation, intermediate, malc and expert track',
#     'project management, pmp, ',
#     'quality management',
#     'prince2®',
#     'six sigma green belt & lean six sigma black belt',
#     'agile & scrum',
#     'msp']
# ['comets', 'astronomy', 'asteroids', 'solar system', 'planetary science']
# []
# [   'birds',
#     'conservation',
#     'wildlife biology',
#     'giraffes',
#     'cameratrap',
#     'biodiversity',
#     'carnivore',
#     'ecology ',
#     'elephants',
#     'africa',
#     'mammals',
#     'reptiles',
#     'wildlife',
#     'mammal',
#     'camera-trap',
#     'nature',
#     'biology',
#     ' lion',
#     'camera']
# ['history']
# []
# []
# ['lordoftheflies ', 'ralph', 'jack', 'civilizationvssavagery', 'literature']
# ['astronomy', 'supernovae', 'physics']
# [   'cultural geography ',
#     'istanbul, smartphone photography, emotions',
#     'visual methods',
#     'urban studies',
#     'social science']
# ['medicine']
# []
# /projects?page=36
# [   'plants',
#     'flower',
#     'ecology ',
#     'wildlife',
#     ' wildlife monitoring',
#     'wildlife biology',
#     'food',
#     'arctic']
# ['video', 'movies', 'clips']
# []
# []
# [   'art',
#     ' environment',
#     'home',
#     'arts',
#     'social science',
#     ' building',
#     'architecture ',
#     'beauty',
#     'shape',
#     'rating']
# ['nature', 'astronomy', 'galaxies', 'classify', 'physics']
# ['astronomy']
# ['history', 'literature', 'arts', 'theater', 'philadelphia']
# [   'nature',
#     'plants',
#     'climate',
#     'biology',
#     ' climate change',
#     ' botany',
#     ' arboretum',
#     ' arnold arboretum',
#     ' harvard university',
#     ' trees',
#     ' shrubs',
#     ' lianas',
#     ' fruits',
#     ' flowers',
#     'photography']
# ['nature', 'ecology ']
# ['astronomy', ' time-series', ' black holes']
# [   'nature',
#     'medicine',
#     'biology',
#     'social science',
#     ' botany',
#     'weed ',
#     'cannabis',
#     'marijuana']
# [   'nature',
#     ' history',
#     'climate',
#     'weather',
#     'rainfall',
#     ' mountains',
#     'meteorology',
#     'scotland',
#     'temperature',
#     'wind ']
# ['nature', 'birds', 'biology', 'london']
# []
# ['nature', 'biology']
# []
# [   'egypt',
#     'digital humanities',
#     'language',
#     'africa',
#     'history',
#     'literature',
#     'arts',
#     'social science',
#     'middle age',
#     'geniza',
#     'genizah',
#     '"cairo geniza"',
#     'cairo genizah',
#     'fatimid',
#     'jewish',
#     'islam',
#     'hebrew',
#     'judeo-arabic',
#     'arab',
#     'arabo-hebrew',
#     'middle east',
#     'europe',
#     'middle ages',
#     'judaicadh',
#     'dh',
#     'upenn',
#     'judaism',
#     'ladino',
#     'yiddish',
#     'asia',
#     'fatimid caliphate',
#     'islamic world',
#     'arab world',
#     'judeo-spanish',
#     'rabbi',
#     'ritual',
#     'jts',
#     'jewish theological seminary',
#     'university of pennsylvania',
#     'cambridge university',
#     'princeton geniza lab']
# [   'science projects',
#     'engineering projects',
#     'ideas for science projects',
#     'kits for science projects',
#     'electronic projects',
#     'electrical projects',
#     'embedded projects',
#     'engineering projetcs',
#     'roborics projects']
# []
# /projects?page=37
# [   ' species',
#     'fauna  ',
#     'citizen science',
#     'identify',
#     'wild animals',
#     ' wildcam',
#     'texas',
#     ' austin',
#     'biodiversity',
#     'identification',
#     ' animal population',
#     'population',
#     'wildlife',
#     'nature',
#     'biology']
# []
# ['nature', 'biology']
# [' carolinas', 'slavery', 'history', ' history', 'social science']
# ['nature']
# ['astronomy', 'galaxy morphology']
# []
# ['astronomy', 'physics']
# []
# []
# []
# ['arts']
# ['пробный проект']
# []
# ['photography', 'arts', 'nature', 'biology']
# ['astronomy', 'physics']
# []
# []
# []
# []
# /projects?page=38
# []
# ['computer vision', 'nature']
# []
# ['nature', 'biology']
# ['animals', 'nature']
# []
# ['nature', 'biology']
# ['astronomy', 'physics', 'tess', 'exoplanets']
# ['astronomy']
# []
# []
# ['k', 'n', 'i', 'i', 'a', 'e', 'nature', 'biology']
# ['#notmyimmigrants #united', 'social science']
# []
# ['medicine', 'biology']
# ['tree', 'green', 'nature']
# ['astronomy', ' star clusters']
# ['astronomy']
# []
# []
# /projects?page=39
# []
# []
# [   'birds',
#     'grouse',
#     'wildlife, conservation',
#     'animal behavior',
#     'nature',
#     'biology',
#     'camera trap']
# ['crime ', 'guns', 'safety', 'social science']
# []
# ['coyote', 'wildlife', 'nature', 'biology', 'camera trap']
# ['assignment help', 'social science']
# ['arts']
# ['adnpr,puerto rico,pasaportes']
# ['biology']
# []
# []
# ['bees', 'bee', 'honey', 'honey bees']
# []
# []
# []
# []
# []
# [   'training data',
#     'serengeti',
#     'wild animals',
#     'image analysis',
#     'drawing boxes',
#     'giraffes',
#     'hooved animals',
#     'snapshot serengeti',
#     'zebra',
#     'guinea fowl',
#     'ostriches',
#     'neural networks',
#     'warthogs',
#     'wildebeest',
#     'hartebeest',
#     'gazelles',
#     'occlusion',
#     'posture',
#     'tanzania',
#     'serengeti national park',
#     'buffalo',
#     'elephants',
#     'africa',
#     'machine learning',
#     'computer vision',
#     'wildlife',
#     'nature']
# []
# /projects?page=40
# []
# ['museums', 'history', 'nature']
# []
# ['nature']
# []
# ['cave', ' pollution', 'animals', 'explore', ' water']
# ['mars ', 'astronomy', 'planetary science']
# []
# ['biology']
# ['effort to help', 'homeless animals', 'help to animals']
# []
# ['songs', ' personal history', ' local history', ' stories', ' anecdotes']
# []
# ['climate', ' history']
# ['pugs']
# []
# []
# ['astronomy']
# []
# []
# /projects?page=41
# ['biology']
# []
# []
# ['astronomy']
# []
# []
# ['grb']
# []
# ['global warming']
# ['history', 'nature', 'biology']
# []
# ['astronomy']
# ['astronomy', 'paired-object systems']
# ['nature']
# ['galaxies', 'astronomy', 'streams', 'galaxy', 'stellar haloes', 'shells']
# []
# ['history']
# [   'ramat hagolan',
#     'רמת הגולן',
#     'טבע',
#     'בעלי חיים',
#     'nature',
#     'social science',
#     'biology']
# []
# ['galaxies', 'astronomy', 'quasars', 'physics']
# /projects?page=42
# []
# ['ant', 'nature', 'biology']
# []
# []
# []
# ['language', 'literature', 'arts']
# []
# ['climate']
# ['australia', 'wildlife', 'camera']
# []
# ['astronomy', 'physics']
# ['astronomy']
# ['literature', 'thomas hardy', 'history']
# []
# []
# []
# [   'birds',
#     ' evolution',
#     'museum',
#     'ornithology',
#     'zoology, birds',
#     'macroevolution',
#     'collections',
#     'zoology',
#     'natural history',
#     'plumage',
#     'colour',
#     'ultraviolet',
#     'bird',
#     'nature',
#     'biology']
# []
# []
# []
# /projects?page=43
# []
# []
# ['astronomy']
# []
# ['astronomy', 'physics']
# ['astronomy']
# []
# ['astronomy']
# []
# []
# ['galaxies', 'stars']
# [' botany', 'taxonomy', 'nature', 'biology']
# []
# ['astronomy']
# []
# ['nature']
# []
# ['photography', 'history', 'arts', 'urban']
# []
# [   'medicine',
#     'cancer ',
#     'hpv',
#     'vaccination',
#     'vaccine',
#     'public health',
#     'social media',
#     'social science',
#     'biology']
# /projects?page=44
# ['astronomy', 'rock', ' mars', ' curiosity']
# []
# []
# []
# []
# ['nature']
# ['biolo']
# []
# ['astronomy', 'arts']
# []
# ['observations', 'home', 'discussion', 'profile']
# [' species', ' habitat', 'wildlife', 'nature', 'biology']
# ['language', 'literature', 'history']
# []
# []
# []
# [' culture', 'architecture ', 'astronomy', 'history', 'social science']
# ['archives', ' language', ' translation', ' transcription', 'documents']
# ['astronomy', 'physics']
# ['horse']
# /projects?page=45
# []
# []
# []
# []
# []
# []
# []
# [   ' pollution',
#     'green',
#     'global warming',
#     'make green',
#     'green planet',
#     'nature']
# []
# ['astronomy', 'physics']
# ['cat', 'biology']
# ['eo', 'waterholes']
# ['nature', 'biology']
# []
# ['machine learning']
# []
# []
# []
# []
# []
# /projects?page=46
# []
# []
# []
# ['computer history', 'climate', 'history']
# []
# ['astronomy', 'climate']
# []
# []
# []
# []
# []
# []
# ['galaxies']
# [   ' solar system',
#     ' fun',
#     ' banter',
#     ' amusing',
#     ' destroy',
#     ' the world',
#     ' death',
#     ' kepler 7898797889bfg',
#     'planets',
#     ' animals']
# []
# []
# ['insects', 'entomology', 'transcription', 'collections']
# ['astronomy', 'astronomy, spirals']
# []
# []
# /projects?page=47
# []
# ['nature']
# []
# [' botany', 'nature', 'biology']
# []
# [   'language',
#     '#psychology #philosophy #linguistics',
#     'arts',
#     'nature',
#     'social science']
# ['bvi']
# []
# []
# []
# ['law', 'literature', 'history']
# []
# []
# []
# []
# ['cheese']
# []
# []
# ['biology']
# []
# /projects?page=48
# []
# []
# []
# []
# []
# []
# []
# []
# ['biology']
# []
# []
# ['biology']
# []
# ['language', 'xd', 'arts', 'social science']
# ['teste', 'physics', 'nature']
# []
# ['climate', 'nature']
# []
# ['animals', 'behavior', 'ornithology', 'bird', 'biology']
# []
# /projects?page=49
# ['nature', 'biology']
# []
# ['astronomy']
# []
# ['social science']
# ['ancient-lives']
# []
# []
# ['duck', 'nature']
# ['astronomy', 'climate']
# ['astronomy']
# []
# []
# ['astronomy', 'asteroids', 'planetary science']
# []
# []
# [   'b',
#     'n',
#     'i',
#     'i',
#     'u',
#     'a',
#     'a',
#     'o',
#     'r',
#     'r',
#     'nature',
#     'biology',
#     'd',
#     'd',
#     'd']
# []
# []
# []
# /projects?page=50
# []
# ['i', 'history']
# []

# %%
df = pd.read_csv('/srv/zooniverse/tables/all_projects_table_05-31-17.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'panoptes_api_classificaitons_count',
#        'panoptes_api_official_project', 'panoptes_api_roles',
#        'panoptes_api_subject_count', 'panoptes_api_workflows',
#        'panoptes_completeness', 'panoptes_description', 'panoptes_launch_date',
#        'panoptes_live', 'panoptes_migrated', 'panoptes_project_id',
#        'panoptes_project_name', 'panoptes_api',
#        'panoptes_dump_classification_count', 'panoptes_dump_workflows',
#        'panoptes_dump', 'ouroboros_mongo_id',
#        'ouroboros_meta_activated_subjects_at',
#        'ouroboros_meta_classification_count', 'ouroboros_meta_complete_count',
#        'ouroboros_meta_created_at', 'ouroboros_project_name',
#        'ouroboros_meta_user_count', 'ouroboros_dump', 'talk'],
#       dtype='object')
