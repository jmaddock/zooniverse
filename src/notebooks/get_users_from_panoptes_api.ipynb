# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')

import requests
import pprint

pp = pprint.PrettyPrinter(indent=4)

# %%
# specify data directory and file
data_dir = '/srv/zooniverse/raw_data/panoptes/all-panoptes-classifications-2017-01-30.csv'
# read csv file of classifications
classification_df = pd.read_csv(data_dir)
# Out:
# /home/sjm668/dev/zooniverse/src/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
base_url = r'https://panoptes-staging.zooniverse.org/api/users'
headers = {
    'Accept':'application/vnd.api+json; version=1',
    'Content-Type':'application/json'
}
params = {}

# %%
r = requests.get(base_url,
                params=params,
                headers=headers)

# %%
r.json()['users']
# Out:
# [{'created_at': '2012-03-14T02:42:39.000Z',
#   'display_name': 'agoxton',
#   'href': '/users/599665',
#   'id': '599665',
#   'links': {},
#   'login': 'agoxton',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880897'},
#  {'created_at': '2012-03-14T02:42:53.000Z',
#   'display_name': 'SANJAY_rawat',
#   'href': '/users/599669',
#   'id': '599669',
#   'links': {},
#   'login': 'SANJAY_rawat',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880903'},
#  {'created_at': '2012-03-14T02:42:55.000Z',
#   'display_name': 'olegnalon',
#   'href': '/users/599672',
#   'id': '599672',
#   'links': {},
#   'login': 'olegnalon',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880906'},
#  {'created_at': '2012-03-14T02:43:10.000Z',
#   'display_name': 'ufoman32',
#   'href': '/users/599675',
#   'id': '599675',
#   'links': {},
#   'login': 'ufoman32',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880910'},
#  {'created_at': '2012-03-14T02:43:21.000Z',
#   'display_name': 'majac5',
#   'href': '/users/599679',
#   'id': '599679',
#   'links': {},
#   'login': 'majac5',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880917'},
#  {'created_at': '2012-03-14T02:43:26.000Z',
#   'display_name': 'grandpa007hawk',
#   'href': '/users/599681',
#   'id': '599681',
#   'links': {},
#   'login': 'grandpa007hawk',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880919'},
#  {'created_at': '2012-03-14T02:43:36.000Z',
#   'display_name': 'champion1984',
#   'href': '/users/599684',
#   'id': '599684',
#   'links': {},
#   'login': 'champion1984',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880923'},
#  {'created_at': '2012-03-14T02:43:39.000Z',
#   'display_name': 'felkins',
#   'href': '/users/599687',
#   'id': '599687',
#   'links': {},
#   'login': 'felkins',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880926'},
#  {'created_at': '2012-03-14T02:43:40.000Z',
#   'display_name': 'Michael pasillas',
#   'href': '/users/599688',
#   'id': '599688',
#   'links': {},
#   'login': 'Michael_pasillas',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880927'},
#  {'created_at': '2012-03-14T02:43:44.000Z',
#   'display_name': 'CTompkins',
#   'href': '/users/599692',
#   'id': '599692',
#   'links': {},
#   'login': 'CTompkins',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880932'},
#  {'created_at': '2012-03-14T02:43:47.000Z',
#   'display_name': 'thope',
#   'href': '/users/599694',
#   'id': '599694',
#   'links': {},
#   'login': 'thope',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880935'},
#  {'created_at': '2012-03-14T02:43:49.000Z',
#   'display_name': 'srv113',
#   'href': '/users/599697',
#   'id': '599697',
#   'links': {},
#   'login': 'srv113',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880938'},
#  {'created_at': '2012-03-14T02:43:52.000Z',
#   'display_name': 'vimal kumar',
#   'href': '/users/599698',
#   'id': '599698',
#   'links': {},
#   'login': 'vimal_kumar',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880939'},
#  {'created_at': '2012-03-14T02:43:53.000Z',
#   'display_name': 'kkum777',
#   'href': '/users/599700',
#   'id': '599700',
#   'links': {},
#   'login': 'kkum777',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880941'},
#  {'created_at': '2012-03-14T02:43:58.000Z',
#   'display_name': 'loualmon',
#   'href': '/users/599703',
#   'id': '599703',
#   'links': {},
#   'login': 'loualmon',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880944'},
#  {'created_at': '2012-03-14T02:44:04.000Z',
#   'display_name': 'bootsoreo',
#   'href': '/users/599706',
#   'id': '599706',
#   'links': {},
#   'login': 'bootsoreo',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880948'},
#  {'created_at': '2012-03-14T02:44:12.000Z',
#   'display_name': 'Rtlansing',
#   'href': '/users/599710',
#   'id': '599710',
#   'links': {},
#   'login': 'Rtlansing',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880953'},
#  {'created_at': '2012-03-14T02:44:25.000Z',
#   'display_name': 'kenny jr',
#   'href': '/users/599714',
#   'id': '599714',
#   'links': {},
#   'login': 'kenny_jr',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880958'},
#  {'created_at': '2012-03-14T02:44:35.000Z',
#   'display_name': 'Rljacks43',
#   'href': '/users/599717',
#   'id': '599717',
#   'links': {},
#   'login': 'Rljacks43',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880961'},
#  {'created_at': '2012-03-14T02:44:41.000Z',
#   'display_name': 'Frankjmtz',
#   'href': '/users/599720',
#   'id': '599720',
#   'links': {},
#   'login': 'Frankjmtz',
#   'private_profile': True,
#   'type': 'users',
#   'updated_at': '2015-10-14T20:17:30.000Z',
#   'zooniverse_id': '880964'}]
