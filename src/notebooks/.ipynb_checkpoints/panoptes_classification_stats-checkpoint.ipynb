# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')

# %%
# specify data directory and file
data_dir = '/srv/zooniverse/raw_data/panoptes/all-panoptes-classifications-2017-01-30.csv'
# read csv file of classifications
classification_df = pd.read_csv(data_dir)

# %%
classification_df['created_at'] = pd.to_datetime(classification_df['created_at'],errors='raise')

# %%
classification_df
# Out:
#                 id  project_id    user_id  workflow_id  \
# 0          6743419         764        NaN         1224
# 1         11726142         593        NaN          338
# 2          6202913         764   494578.0         1224
# 3          6203037         764  1427984.0         1224
# 4          6203440         764   965965.0         1224
# 5          6203753         764        NaN         1224
# 6          6204127         764   704675.0         1224
# 7          6206895         764  1174363.0         1224
# 8          6207383         764  1427236.0         1224
# 9          6207909         764  1428089.0         1224
# 10         6208983         764  1428474.0         1224
# 11         7037999         764  1430421.0         1224
# 12         6743420         764  1428115.0         1224
# 13         6202914         764        NaN         1224
# 14         6203476         764        NaN         1224
# 15         6204071         764   671884.0         1224
# 16         6204241         764        NaN         1224
# 17         6204309         764  1427487.0         1224
# 18         6216489         764  1428330.0         1224
# 19         6216668         764   487375.0         1224
# 20         6216996         764  1428554.0         1224
# 21         6217750         764  1427207.0         1224
# 22        11720618           3        NaN         1623
# 23         6202915         764        NaN         1224
# 24         6202997         764        NaN         1224
# 25         6203499         764  1427839.0         1224
# 26         6203596         764   419222.0         1224
# 27         6203953         764        NaN         1224
# 28         6204910         764  1428364.0         1224
# 29         6204979         764   707425.0         1224
# ...            ...         ...        ...          ...
# 26116408   6202910         764   337766.0         1224
# 26116409   6203364         764  1428054.0         1224
# 26116410   6203655         764        NaN         1224
# 26116411   6203714         764        NaN         1224
# 26116412   6204894         764     3600.0         1224
# 26116413   6205620         764  1427409.0         1224
# 26116414   6206359         764  1427190.0         1224
# 26116415   6206941         764        NaN         1224
# 26116416   6216484         764        NaN         1224
# 26116417   7037998         764  1427519.0         1224
# 26116418   6202911         764        NaN         1224
# 26116419   6202956         764        NaN         1224
# 26116420   6203009         764        NaN         1224
# 26116421   6204518         764  1428033.0         1224
# 26116422   6206020         764        NaN         1224
# 26116423   6206681         764  1428384.0         1224
# 26116424   6206939         764        NaN         1224
# 26116425   6207105         764  1428084.0         1224
# 26116426   6207469         764     1723.0         1224
# 26116427   6208447         764     1181.0         1224
# 26116428   6743418         764  1429175.0         1224
# 26116429   6597832         724  1428236.0          488
# 26116430   6743466         764   517041.0         1224
# 26116431   6202912         764        NaN         1224
# 26116432   6202967         764     1654.0         1224
# 26116433   6598404         764   733447.0         1224
# 26116434   6203701         764    46314.0         1224
# 26116435   6204011         764        NaN         1224
# 26116436   6598868         764  1261510.0         1224
# 26116437   6204727         764  1427476.0         1224
#
#                                                 annotations  \
# 0                            [{"task": "init", "value": 1}]
# 1         [{"task": "T1", "value": [{"choice": "NTHNGHR"...
# 2                            [{"task": "init", "value": 1}]
# 3                            [{"task": "init", "value": 1}]
# 4                            [{"task": "init", "value": 1}]
# 5                            [{"task": "init", "value": 1}]
# 6                            [{"task": "init", "value": 1}]
# 7                            [{"task": "init", "value": 1}]
# 8                            [{"task": "init", "value": 1}]
# 9                            [{"task": "init", "value": 1}]
# 10                           [{"task": "init", "value": 1}]
# 11                           [{"task": "init", "value": 1}]
# 12                           [{"task": "init", "value": 1}]
# 13                           [{"task": "init", "value": 1}]
# 14                           [{"task": "init", "value": 0}]
# 15                           [{"task": "init", "value": 1}]
# 16                           [{"task": "init", "value": 1}]
# 17                           [{"task": "init", "value": 1}]
# 18                           [{"task": "init", "value": 1}]
# 19                           [{"task": "init", "value": 1}]
# 20                           [{"task": "init", "value": 1}]
# 21                           [{"task": "init", "value": 1}]
# 22                           [{"task": "init", "value": 0}]
# 23                           [{"task": "init", "value": 1}]
# 24                           [{"task": "init", "value": 1}]
# 25                           [{"task": "init", "value": 1}]
# 26                           [{"task": "init", "value": 1}]
# 27                           [{"task": "init", "value": 1}]
# 28                           [{"task": "init", "value": 1}]
# 29                           [{"task": "init", "value": 1}]
# ...                                                     ...
# 26116408                     [{"task": "init", "value": 1}]
# 26116409                     [{"task": "init", "value": 1}]
# 26116410                     [{"task": "init", "value": 1}]
# 26116411                     [{"task": "init", "value": 1}]
# 26116412                     [{"task": "init", "value": 1}]
# 26116413                     [{"task": "init", "value": 1}]
# 26116414                     [{"task": "init", "value": 1}]
# 26116415                     [{"task": "init", "value": 1}]
# 26116416                     [{"task": "init", "value": 1}]
# 26116417                     [{"task": "init", "value": 1}]
# 26116418                     [{"task": "init", "value": 1}]
# 26116419                     [{"task": "init", "value": 1}]
# 26116420                     [{"task": "init", "value": 1}]
# 26116421                     [{"task": "init", "value": 1}]
# 26116422                     [{"task": "init", "value": 1}]
# 26116423                     [{"task": "init", "value": 1}]
# 26116424                     [{"task": "init", "value": 1}]
# 26116425                     [{"task": "init", "value": 0}]
# 26116426                     [{"task": "init", "value": 1}]
# 26116427                     [{"task": "init", "value": 1}]
# 26116428                     [{"task": "init", "value": 1}]
# 26116429  [{"task": "init", "value": 1}, {"task": "T1", ...
# 26116430                     [{"task": "init", "value": 1}]
# 26116431                     [{"task": "init", "value": 1}]
# 26116432                     [{"task": "init", "value": 1}]
# 26116433                     [{"task": "init", "value": 1}]
# 26116434                     [{"task": "init", "value": 1}]
# 26116435                     [{"task": "init", "value": 1}]
# 26116436                     [{"task": "init", "value": 1}]
# 26116437                     [{"task": "init", "value": 1}]
#
#                          created_at               user_group_id completed  \
# 0        2016-01-13 07:46:03.869156   2016-01-13 07:46:03.92731         t
# 1        2016-04-26 20:16:43.011371  2016-04-26 20:16:43.102913         t
# 2        2016-01-12 22:43:51.800876  2016-01-12 22:44:34.862261         t
# 3        2016-01-12 22:43:57.000614  2016-01-12 22:44:37.329617         t
# 4        2016-01-12 22:44:09.625892  2016-01-12 22:44:44.650376         t
# 5        2016-01-12 22:44:22.724827  2016-01-12 22:44:50.200208         t
# 6        2016-01-12 22:44:42.237560  2016-01-12 22:44:57.491331         t
# 7        2016-01-12 22:46:32.920905  2016-01-12 22:46:34.669368         t
# 8        2016-01-12 22:46:50.704562  2016-01-12 22:46:51.676811         t
# 9        2016-01-12 22:47:10.587072  2016-01-12 22:47:11.466133         t
# 10       2016-01-12 22:47:54.554520  2016-01-12 22:47:57.469887         t
# 11       2016-01-13 13:37:32.294225  2016-01-13 13:37:32.456227         t
# 26116430 2016-01-13 07:46:14.169654  2016-01-13 07:46:14.224749         t
# 26116431 2016-01-12 22:43:51.773838  2016-01-12 22:44:35.399945         t
# 26116432 2016-01-12 22:43:54.553912  2016-01-12 22:44:35.662867         t
# 26116433 2016-01-13 00:52:10.634599  2016-01-13 00:52:24.448538         t
# 26116434 2016-01-12 22:44:19.859469  2016-01-12 22:44:49.289346         t
# 26116435 2016-01-12 22:44:36.529991  2016-01-12 22:44:55.311636         t
# 26116436 2016-01-13 00:52:29.379194    2016-01-13 00:52:45.5256         t
# 26116437 2016-01-12 22:45:07.024252  2016-01-12 22:45:08.976941         t
#
#          gold_standard  expert_classifier  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# 5                  NaN                NaN
# 6                  NaN                NaN
# 7                  NaN                NaN
# 8                  NaN                NaN
# 9                  NaN                NaN
# 10                 NaN                NaN
# 11                 NaN                NaN
# 12                 NaN                NaN
# 13                 NaN                NaN
# 14                 NaN                NaN
# 15                 NaN                NaN
# 16                 NaN                NaN
# 17                 NaN                NaN
# 18                 NaN                NaN
# 19                 NaN                NaN
# 20                 NaN                NaN
# 21                 NaN                NaN
# 22                 NaN                NaN
# 23                 NaN                NaN
# 24                 NaN                NaN
# 25                 NaN                NaN
# 26                 NaN                NaN
# 27                 NaN                NaN
# 28                 NaN                NaN
# 29                 NaN                NaN
# ...                ...                ...
# 26116408           NaN                NaN
# 26116409           NaN                NaN
# 26116410           NaN                NaN
# 26116411           NaN                NaN
# 26116412           NaN                NaN
# 26116413           NaN                NaN
# 26116414           NaN                NaN
# 26116415           NaN                NaN
# 26116416           NaN                NaN
# 26116417           NaN                NaN
# 26116418           NaN                NaN
# 26116419           NaN                NaN
# 26116420           NaN                NaN
# 26116421           NaN                NaN
# 26116422           NaN                NaN
# 26116423           NaN                NaN
# 26116424           NaN                NaN
# 26116425           NaN                NaN
# 26116426           NaN                NaN
# 26116427           NaN                NaN
# 26116428           NaN                NaN
# 26116429           NaN                NaN
# 26116430           NaN                NaN
# 26116431           NaN                NaN
# 26116432           NaN                NaN
# 26116433           NaN                NaN
# 26116434           NaN                NaN
# 26116435           NaN                NaN
# 26116436           NaN                NaN
# 26116437           NaN                NaN
#
#                                                    metadata  workflow_version  \
# 0         {"session": "6447163787569179c92064dac989cc6b6...             4.500
# 1         {"viewport": {"width": 1366, "height": 665}, "...          1890.180
# 2         {"session": "3c233ce5e308cc9af8cb2aeb85a449640...             4.500
# 3         {"session": "df80959b6695fcd676a1202ebf1092491...             4.500
# 4         {"session": "e8cf8ac76855a88928dda306206fa2f80...             4.500
# 5         {"session": "c581c7187116f44178ba479667deb68a2...             4.500
# 6         {"session": "6c865e98ff9215843d3114d448c2d7753...             4.500
# 7         {"session": "6c8e8d567beaf7a5bca32c2ec64bcb1f1...             4.500
# 8         {"session": "5d329e17356b5fb82d73688b020f1e87d...             4.500
# 9         {"session": "7e25208586f47c62b7c2c43d32a0db8a4...             4.500
# 10        {"session": "4edfe0c32f9f7376e22a8741e728f9604...             4.500
# 11        {"session": "af8c256ac1e4b394375d5fee5413c94fb...             4.500
# 12        {"session": "bec213f53a5a7f4890b9991f638648aaa...             4.500
# 13        {"session": "d48a27be4323a3cffbc2d99eedce208e1...             4.500
# 14        {"session": "dbce20773a3da115709c4871e1bf698e5...             4.500
# 15        {"session": "db45ec019c19a7ad0b67955b80513cadb...             4.500
# 16        {"session": "c0065b9c5efff4fc93d12c5285a75f512...             4.500
# 17        {"session": "1fb2b5410c6d74445537d6b9bb495d49f...             4.500
# 18        {"session": "9bc64fd29d31fde968c70624fe72de63a...             4.500
# 19        {"session": "57eb8894f0ffc44d72e8bbec1638a7443...             4.500
# 20        {"session": "b81d35ecdb90e0e88dd7a98d1df40c32f...             4.500
# 21        {"session": "c650175a54f70e186efbdd5329252d6c0...             4.500
# 22        {"session": "92bd27e6797f9b0cd7bcf7b09c0acf01f...             5.160
# 23        {"session": "2955c62ca8754f5b86eb36cf836e80be1...             4.500
# 24        {"session": "a22fd1484c1f8a908755712e534751692...             4.500
# 25        {"session": "7e32404c28b2ad93079dae1c46d7936e3...             4.500
# 26        {"session": "f2a40f1a5b765e11181f1ad7a9c111e78...             4.500
# 27        {"session": "f78833fe778e7f1227196969603f485ae...             4.500
# 28        {"session": "d562fe8e7055204d7e57e20658e252553...             4.500
# 29        {"session": "3ffeb7d6c11e4e0c5f6b47e764b897904...             4.500
# ...                                                     ...               ...
# 26116408  {"session": "de00f6a53c11c29c86761221da638236c...             4.500
# 26116409  {"session": "b38b100dc43354122eedfd8489e211311...             4.500
# 26116410  {"session": "833cf72fce10f1d59b705e01c89a699fb...             4.500
# 26116411  {"session": "e11b4c596e80e9f64bc09a90d6a422b13...             4.500
# 26116412  {"session": "a426d8bae274cd1601a23a1d16733b907...             4.500
# 26116413  {"session": "32b9e69e3792851d0b982036cebcae7d1...             4.500
# 26116414  {"session": "42ca74868dd3614c336bfc306e4998f5d...             4.500
# 26116415  {"session": "ea8e8e511b2aa343c6ef9342626763e9b...             4.500
# 26116416  {"session": "3cecc7c916e203cf7c156ba07b98ef150...             4.500
# 26116417  {"session": "5ad6c36ff7fd3fcfd2dda7ccfbb05a874...             4.500
# 26116418  {"session": "da93af6e723f69e5ca0843daedf61e212...             4.500
# 26116419  {"session": "01ffa30769bdc84ccb959fb9f1b6f282b...             4.500
# 26116420  {"session": "3eaef7b975c33fec578bcde6f6d735863...             4.500
# 26116421  {"session": "79ff8cd2cc0b8f3e6e7517a9957f3128e...             4.500
# 26116422  {"session": "1f5b5ba6cfb08144fa46e99408c00f2be...             4.500
# 26116423  {"session": "2dc29695de7150f25f317e417ea80b7f4...             4.500
# 26116424  {"session": "6d19777ca0cc737523f4b9fdd2ae5bac2...             4.500
# 26116425  {"session": "8117f42b14ca522dd2aab5e01b10e81c7...             4.500
# 26116426  {"session": "b1ae2fd0efa345765658d80d019de1771...             4.500
# 26116427  {"session": "c61b00ed5e5bc9691009267afb87cd762...             4.500
# 26116428  {"session": "feb3f5a21b2fe484a4142f675804c6336...             4.500
# 26116429  {"session": "832f7094a49a5dfb9881baae91a3b24f0...            47.408
# 26116430  {"session": "cdfffcb0adf666237c80197de0070e83d...             4.500
# 26116431  {"session": "db6c3b96e3d43e9c5dadb65f7b01185e1...             4.500
users_per_project = classification_df.groupby('project_id')['user_id'].nunique().to_frame('total_users')
# merge with project_df
project_df = project_df.merge(users_per_project,left_index=True,right_index=True)

# %%
# create a use dataframe for number of classifications per user
user_df = classification_df.groupby('user_id').size().to_frame('total_classifications')
# get the number of projects per user
projects_per_user = classification_df.groupby('user_id')['project_id'].nunique().to_frame('total_projects')
# merge with user_df
user_df = user_df.merge(projects_per_user,left_index=True,right_index=True).reset_index()

# %%
# get the first and last classification for each user
sorted_by_dates = classification_df[['user_id','created_at']].sort_values(by='created_at')
first_classification = sorted_by_dates.drop_duplicates(subset='user_id',keep='first').rename(columns={'created_at':'first_classification'})
last_classification = sorted_by_dates.drop_duplicates(subset='user_id',keep='last').rename(columns={'created_at':'last_classification'})
user_df = user_df.merge(first_classification,on='user_id').merge(last_classification,on='user_id')

# %%
# number of projects
len(classification_df['project_id'].unique())
# Out:
# 750

# %%
# total number of classifications
len(classification_df)
# Out:
# 26116438

# %%
# total number of users
len(classification_df['user_id'].unique())
# Out:
# 87223

# %%
# number of projects with gold standard data
len(classification_df.loc[df['gold_standard'] == 't'])
# Out:
# 10101

# %%
# values for expert classifier
classification_df['expert_classifier'].unique()
# Out:
# array([ nan,   0.,   1.])

# %%
# counts for each value of expert classifier
classification_df.groupby('expert_classifier').size()
# Out:
# expert_classifier
# 0.0    7457
# 1.0     942
# dtype: int64

# %%
# classifications without expert classifier
len(classification_df.loc[df['expert_classifier'].isnull()])
# Out:
# 26108039

# %%
# classifications with expert classifier
len(classification_df.loc[df['expert_classifier'].notnull()])
# Out:
# 8399

# %%
project_df.describe(percentiles=np.arange(0,1,0.1))
# Out:
#        total_classifications   total_users
# count           7.500000e+02    750.000000
# mean            3.482192e+04    233.526667
# std             2.542708e+05   1135.739423
# min             1.000000e+00      1.000000
# 0%              1.000000e+00      1.000000
# 10%             1.000000e+00      1.000000
# 20%             3.000000e+00      1.000000
# 30.0%           5.000000e+00      1.000000
# 40%             9.000000e+00      1.000000
# 50%             1.700000e+01      1.000000
# 60.0%           3.300000e+01      2.000000
# 70%             7.690000e+01      4.000000
# 80%             2.466000e+02      9.000000
# 90%             5.339300e+03     97.100000
# max             4.181735e+06  16227.000000

# %%
project_df.hist('total_classifications',bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f75a8887cf8>]], dtype=object)

# %%
user_df.describe(percentiles=np.arange(0,1,0.1))
# Out:
#        total_classifications  total_projects
# count           87222.000000    87222.000000
# mean              234.806712        2.008037
# std              1928.976396        2.698327
# min                 1.000000        1.000000
# 0%                  1.000000        1.000000
# 10%                 3.000000        1.000000
# 20%                 6.000000        1.000000
# 30.0%              12.000000        1.000000
# 40%                19.000000        1.000000
# 50%                30.000000        1.000000
# 60.0%              47.000000        1.000000
# 70%                79.000000        2.000000
# 80%               148.000000        2.000000
# 90%               364.000000        4.000000
# max            213754.000000      111.000000

# %%
user_df.hist('total_classifications',bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f75a83aba58>]], dtype=object)

# %%
# number of classifications that don't have a user id
len(classification_df.loc[classification_df['user_id'].isnull()])
# Out:
# 5636127

# %%
# percent of classifications that don't have a user id
len(classification_df.loc[classification_df['user_id'].isnull()])/len(classification_df)
# Out:
# 0.21580764574403294
