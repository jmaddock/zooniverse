# %%
import mailbox
from datetime import datetime
from datetime import timedelta
import re

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')

from scipy import stats

# %% [markdown]
# # Load and Clean Data

# %%
email_df = pd.read_csv('/srv/zooniverse/tables/emails.csv')
category_df = pd.read_csv('/srv/zooniverse/tables/project_categories_3-12-19.csv')
project_df = pd.read_csv('/srv/zooniverse/tables/all_projects_table_02-18-19.csv')

# %%
# only use "official" projects and classifications
project_df = project_df.loc[(project_df['panoptes_api_official_project'] == 1)]

# only include panoptes projects that also have classification data
project_df = project_df.loc[(project_df['panoptes_dump'] == 1) & (project_df['panoptes_api'] == 1)]

# convert email timestamp to datetime
email_df['date'] = pd.to_datetime(email_df['date'])

#lowercase project names
email_df['project'] = email_df['project'].str.lower()
category_df['project_name'] = category_df['project_name'].str.lower()
project_df['panoptes_project_name'] = project_df['panoptes_project_name'].str.lower()

# %%
# get names of projects for which we have email, category, and classification data
overlapping_projects = category_df.loc[(category_df['project_name'].str.lower().isin(project_df['panoptes_project_name'].str.lower())) & (category_df['project_name'].str.lower().isin(email_df['project'].str.lower()))][['project_name']]

# %%
# load classification df
classification_df = pd.read_csv('/srv/zooniverse/tables/all_classifications_table_02-18-19.csv')
# Out:
# /home/sjm668/dev/zooniverse/src/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# only use "official" projects and classifications
classification_df = classification_df.loc[classification_df['panoptes_api_official_project'] == 1]

# add name column to classification_df
classification_df = classification_df.merge(project_df[['panoptes_project_name','panoptes_project_id']],on='panoptes_project_id')

# online use projects with email, category, and classification data
classification_df = classification_df.loc[classification_df['panoptes_project_name'].str.lower().isin(overlapping_projects['project_name'].str.lower())]

# convert classification timestamp to datetime
classification_df['created_at'] = pd.to_datetime(classification_df['created_at'])

# %%
def get_weeks(x):
    return x.isocalendar()[0]*52+x.isocalendar()[1]

classification_df['iso_week'] = classification_df['created_at'].apply(get_weeks)
email_df['iso_week'] = email_df['date'].apply(get_weeks)

# %%
def count_classifications_per_week(classification_df):
    # grouby weeks and count classifications per week
    classifications_by_week = classification_df.groupby(['panoptes_project_name','iso_week'])['iso_week'].size().to_frame('classifications')
    # reindex to fill missing values
    classifications_by_week = classifications_by_week.reindex(pd.MultiIndex.from_product(classifications_by_week.index.levels, names=classifications_by_week.index.names))
    classifications_by_week.reset_index(inplace=True)
    # switch NaN to 0
    classifications_by_week['classifications'] = classifications_by_week['classifications'].fillna(0)
    return classifications_by_week

# grouby weeks and count classifications per week
classifications_by_week = count_classifications_per_week(classification_df)

# %%
# remove emails sent later than panoptes classification data
email_df = email_df.loc[email_df['iso_week'] < classification_df['iso_week'].max()]

# %%
# remove duplicate email
email_df = email_df.drop_duplicates(subset=['project','iso_week'])

# %% [markdown]
# # Don't run this

# %%
# remove emails from subsequent weeks
email_df = email_df.loc[~email_df['iso_week'].isin(email_df['iso_week'].add(1))]

# %% [markdown]
# # Transform Data

# %%
# log transform classifications
log_classifications_by_week = classifications_by_week.copy()
log_classifications_by_week['classifications'] = np.log1p(classifications_by_week['classifications'])

# %%
def ttest(classifications_by_week, email_df, window=1, ranked=False):

    '''# group classifications by project and iso_week
    classifications_by_week = classification_df.groupby(['panoptes_project_id','iso_week'])['iso_week'].size()
    # add 0s for missing weeks
    classifications_by_week = classifications_by_week.reindex(pd.MultiIndex.from_product(classifications_by_week.index.levels, names=classifications_by_week.index.names),fill_value=0)
    classifications_by_week = classifications_by_week.to_frame('classification_count').reset_index()'''
    
    # create dfs with start and end iso_weeks
    start = email_df['iso_week'].subtract(window).to_frame('start')
    end = email_df['iso_week'].add(window-1).to_frame('end')
    windowed_classifications_by_week_start = classifications_by_week.loc[(classifications_by_week['iso_week'].isin(start['start']))]
    windowed_classifications_by_week_end = classifications_by_week.loc[(classifications_by_week['iso_week'].isin(end['end']))]
    
    # merge start and end week classification counts into single df
    windowed_classifications_by_week_end = windowed_classifications_by_week_end.rename(columns={'iso_week':'iso_week_y'})
    windowed_classifications_by_week_end['iso_week_x'] = windowed_classifications_by_week_end['iso_week_y'].subtract(1)
    windowed_classifications_by_week_start = windowed_classifications_by_week_start.rename(columns={'iso_week':'iso_week_x'})
    windowed_classifications_by_week = windowed_classifications_by_week_start.merge(windowed_classifications_by_week_end,on=['panoptes_project_name','iso_week_x'])
    
    # only include weeks where there was at least one classification before or after the newsletter
    windowed_classifications_by_week = windowed_classifications_by_week.loc[(windowed_classifications_by_week['classifications_x'] > 0) | (windowed_classifications_by_week['classifications_y'] > 0)]
    if ranked:
        ttest = stats.wilcoxon(windowed_classifications_by_week['classifications_y'].values,
                               windowed_classifications_by_week['classifications_x'].values)
    else:
        ttest = stats.ttest_rel(windowed_classifications_by_week['classifications_y'].values,
                                windowed_classifications_by_week['classifications_x'].values)
    
    print(windowed_classifications_by_week[['classifications_x','classifications_y']].describe())
    print('statistic: {0}\np value: {1})'.format(ttest.statistic,ttest.pvalue))

# %%
def classifications_by_time(classifications_by_week, email_df, title=None):
    #classification_df['iso_week'] = classification_df['created_at'].apply(get_weeks)
    #classifications_by_week = classification_df.merge(project_df[['panoptes_project_name','panoptes_project_id']],on='panoptes_project_id',how='left')
    classifications_by_week = classifications_by_week.set_index(['panoptes_project_name','iso_week'])
    classifications_by_week = classifications_by_week.reindex(pd.MultiIndex.from_product(classifications_by_week.index.levels, names=classifications_by_week.index.names),fill_value=0)['classifications'].unstack(level=0)

    classifications_by_week.plot(figsize=(12,12))
    
    #email_df['iso_week'] = email_df['date'].apply(get_weeks)
    plt.vlines(x=email_df.loc[email_df['iso_week'] < classification_df['iso_week'].max()]['iso_week'].tolist(),
               ymin=0,
               ymax=classifications_by_week.max().max(),
               linestyles='dashed',
               lw=1)
    
    plt.xlabel('ISO Date (Years * 52 + Weeks)')
    plt.ylabel('Number of Classifications')
    plt.tight_layout()
    
    if title:
        plt.title(title)

# %% [markdown]
# # T-Test: all projects, all topics
# Perform a for the difference in means between classifications per project the week before the newsletter and the week of the newsletter

# %%
ttest(classifications_by_week=log_classifications_by_week,
      email_df=email_df)
# Out:
#        classifications_x  classifications_y
# count         139.000000         139.000000
# mean            4.378861           4.786006
# std             3.526837           3.689208
# min             0.000000           0.000000
# 25%             1.497866           1.868835
# 50%             3.433987           3.433987
# 75%             7.320805           7.472278
# max            12.663953          12.663953
# statistic: 2.357144413967696
# p value: 0.019821368693800006)

# %%
def add_email_offset(email_df):
    email_offset = email_df.copy()
    email_offset['iso_week'] = email_offset['iso_week'].subtract(1)
    email_df = email_df.append(email_offset)
    return email_df

def filter_targeted(classifications_by_week, email_df, remove_targeted=True):
    classification_index = classifications_by_week.rename(columns={'panoptes_project_name':'project'}).set_index(['project','iso_week']).index
    email_index = add_email_offset(email_df).set_index(['project','iso_week']).index
    print('removed:')
    if remove_targeted:
        print(classifications_by_week[classification_index.isin(email_index)])
        classifications_by_week = classifications_by_week[~classification_index.isin(email_index)]
    
    else:
        print(classifications_by_week[~classification_index.isin(email_index)])
        classifications_by_week = classifications_by_week[classification_index.isin(email_index)]        
    
    return classifications_by_week

# %% [markdown]
# # T-Test: non-targetted projects (all topics)
# Remove all observations where a project was the target of a newsletter

# %%
c = filter_targeted(classifications_by_week=log_classifications_by_week,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df)
# Out:
# removed:
#        panoptes_project_name  iso_week  classifications
# 342         camera catalogue    104862         7.901007
# 343         camera catalogue    104863        12.663953
# 484   decoding the civil war    104856         2.564949
# 485   decoding the civil war    104857         9.005282
# 867           mapping change    104869         0.000000
# 868           mapping change    104870         8.783549
# 1009        radio meteor zoo    104863         5.883322
# 1010        radio meteor zoo    104864        10.458636
# 1219      snapshot wisconsin    104851         9.494842
# 1220      snapshot wisconsin    104852        12.107528
# 1320            snow spotter    104878         3.713572
# 1321            snow spotter    104879        11.025588
#        classifications_x  classifications_y
# count         130.000000         130.000000
# mean            4.272533           4.454332
# std             3.497358           3.500516
# min             0.000000           0.000000
# ...

# %%
c = filter_targeted(classifications_by_week=log_classifications_by_week,
                    email_df=email_df,
                    remove_targeted=False)

ttest(classifications_by_week=c,
      email_df=email_df)
# Out:
# removed:
#      panoptes_project_name  iso_week  classifications
# 0      amazoncam tambopata    104804         0.000000
# 1      amazoncam tambopata    104805         0.000000
# 2      amazoncam tambopata    104806         0.000000
# 3      amazoncam tambopata    104807         0.000000
# 4      amazoncam tambopata    104808         0.000000
# 5      amazoncam tambopata    104810         0.000000
# 6      amazoncam tambopata    104817         0.000000
# 7      amazoncam tambopata    104818         0.000000
# 8      amazoncam tambopata    104821         0.000000
# 9      amazoncam tambopata    104825         0.000000
# 10     amazoncam tambopata    104826         0.000000
# 11     amazoncam tambopata    104827         0.000000
# 12     amazoncam tambopata    104828         0.000000
# 13     amazoncam tambopata    104829         0.000000
# 14     amazoncam tambopata    104830         0.000000
# 15     amazoncam tambopata    104831         0.000000
# ...

# %%
def clean_set(x):
    return x[1:-1].replace("'","").replace(' ','').replace(',','|')

def split_set(x):
    return x.split('|')

def get_category_dummies(df):
    df['categories'] = df['categories'].apply(clean_set)
    columns = df['categories'].str.get_dummies().columns.tolist()
    df = df.merge(df['categories'].str.get_dummies(), left_index=True, right_index=True)
    return df, columns

def filter_by_category(classifications_by_week, email_df, category_df, remove_targeted=True):
    
    # make sure the column names match and merge w/ categories
    email_category_df = add_email_offset(email_df).merge(category_df.rename(columns={'project_name':'project'}),on='project')
    classification_category_df = classifications_by_week.merge(category_df.rename(columns={'project_name':'panoptes_project_name'}),on='panoptes_project_name')

    # turn the category column into a list
    email_category_df['categories'] = email_category_df['categories'].apply(clean_set).apply(split_set)

    # create a df to keep track of removed rows
    removed = pd.DataFrame()
    
    #iterate through all emails in the email df
    for email in email_category_df.itertuples():
        #iterate through all the categories in each project
        for category in email.categories:
            # keep track of removed rows
            if remove_targeted:
                removed = removed.append(classification_category_df.loc[(classification_category_df['iso_week'] == email.iso_week) & (classification_category_df['categories'].str.contains(category))])
                # remove rows that have the same iso_week and category as the email
                classification_category_df = classification_category_df.loc[~((classification_category_df['iso_week'] == email.iso_week) & (classification_category_df['categories'].str.contains(category)))]
            else:
                removed = removed.append(classification_category_df.loc[(classification_category_df['iso_week'] == email.iso_week) & ~(classification_category_df['categories'].str.contains(category))])
                # remove rows that have the same iso_week and category as the email
                classification_category_df = classification_category_df.loc[~((classification_category_df['iso_week'] == email.iso_week) & ~(classification_category_df['categories'].str.contains(category)))]
            
    print('removed {0} rows'.format(len(removed)))

    return classification_category_df
        
#email_category_df, categories = get_category_dummies(email_category_df)
#classification_category_df = get_category_dummies(classification_category_df)[0]

# %% [markdown]
# # T-Test: non-targetted projects & targeted topics
# Remove all observations where a project was the target of a newsletter, and all projects that had the same topic as the newsletter

# %%
c = filter_by_category(classifications_by_week=log_classifications_by_week,
                       email_df=email_df,
                       category_df=category_df)

c = filter_targeted(classifications_by_week=c,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df)
# Out:
# removed 152 rows
# removed:
# Empty DataFrame
# Columns: [panoptes_project_name, iso_week, classifications, categories]
# Index: []
#        classifications_x  classifications_y
# count          85.000000          85.000000
# mean            4.531983           4.762186
# std             3.262657           3.302964
# min             0.000000           0.000000
# 25%             1.791759           2.079442
# 50%             3.871201           3.496508
# 75%             7.380879           7.248504
# max            11.608345          11.683900
# statistic: 1.373346661588914
# p value: 0.17329921799412001)

# %% [markdown]
# # T-Test: non-targetted projects & non-targeted topics
# Remove all observations where a project was the target of a newsletter, and all projects that had the a different topic as the project targeted in the newsletter

# %%
c = filter_by_category(classifications_by_week=log_classifications_by_week,
                       email_df=email_df,
                       category_df=category_df,
                       remove_targeted=False)

c = filter_targeted(classifications_by_week=c,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df)
# Out:
# removed 202 rows
# removed:
#        panoptes_project_name  iso_week  classifications  \
# 342         camera catalogue    104862         7.901007
# 484   decoding the civil war    104856         2.564949
# 485   decoding the civil war    104857         9.005282
# 867           mapping change    104869         0.000000
# 868           mapping change    104870         8.783549
# 1010        radio meteor zoo    104864        10.458636
# 1219      snapshot wisconsin    104851         9.494842
# 1220      snapshot wisconsin    104852        12.107528
# 1320            snow spotter    104878         3.713572
# 1321            snow spotter    104879        11.025588
#
#                             categories
# 342              {'Biology', 'Nature'}
# 484                        {'History'}
# 485                        {'History'}
# 867   {'Biology', 'Nature', 'Climate'}
# 868   {'Biology', 'Nature', 'Climate'}
# 1010                       {'Physics'}
# ...

# %% [markdown]
# # wilcoxon signed-rank test: all projects, all topics
# Perform a for the difference in means between classifications per project the week before the newsletter and the week of the newsletter

# %%
ttest(classifications_by_week=log_classifications_by_week,
      email_df=email_df,
      ranked=True)
# Out:
#        classifications_x  classifications_y
# count         139.000000         139.000000
# mean            4.378861           4.786006
# std             3.526837           3.689208
# min             0.000000           0.000000
# 25%             1.497866           1.868835
# 50%             3.433987           3.433987
# 75%             7.320805           7.472278
# max            12.663953          12.663953
# statistic: 4370.0
# p value: 0.3658125923049539)

# %% [markdown]
# # wilcoxon signed-rank test: non-targetted projects (all topics)
# Remove all observations where a project was the target of a newsletter

# %%
c = filter_targeted(classifications_by_week=log_classifications_by_week,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df,
      ranked=True)
# Out:
# removed:
#        panoptes_project_name  iso_week  classifications
# 342         camera catalogue    104862         7.901007
# 343         camera catalogue    104863        12.663953
# 484   decoding the civil war    104856         2.564949
# 485   decoding the civil war    104857         9.005282
# 867           mapping change    104869         0.000000
# 868           mapping change    104870         8.783549
# 1009        radio meteor zoo    104863         5.883322
# 1010        radio meteor zoo    104864        10.458636
# 1219      snapshot wisconsin    104851         9.494842
# 1220      snapshot wisconsin    104852        12.107528
# 1320            snow spotter    104878         3.713572
# 1321            snow spotter    104879        11.025588
#        classifications_x  classifications_y
# count         130.000000         130.000000
# mean            4.272533           4.454332
# std             3.497358           3.500516
# min             0.000000           0.000000
# ...

# %%
c = filter_targeted(classifications_by_week=log_classifications_by_week,
                    email_df=email_df,
                    remove_targeted=False)

ttest(classifications_by_week=c,
      email_df=email_df,
      ranked=True)
# Out:
# removed:
#      panoptes_project_name  iso_week  classifications
# 0      amazoncam tambopata    104804         0.000000
# 1      amazoncam tambopata    104805         0.000000
# 2      amazoncam tambopata    104806         0.000000
# 3      amazoncam tambopata    104807         0.000000
# 4      amazoncam tambopata    104808         0.000000
# 5      amazoncam tambopata    104810         0.000000
# 6      amazoncam tambopata    104817         0.000000
# 7      amazoncam tambopata    104818         0.000000
# 8      amazoncam tambopata    104821         0.000000
# 9      amazoncam tambopata    104825         0.000000
# 10     amazoncam tambopata    104826         0.000000
# 11     amazoncam tambopata    104827         0.000000
# 12     amazoncam tambopata    104828         0.000000
# 13     amazoncam tambopata    104829         0.000000
# 14     amazoncam tambopata    104830         0.000000
# 15     amazoncam tambopata    104831         0.000000
# ...

# %% [markdown]
# # wilcoxon signed-rank test: targetted projects & non-targeted topics
# Remove all observations where a project was the target of a newsletter, and all projects that had the same topic as the newsletter

# %%
c = filter_by_category(classifications_by_week=log_classifications_by_week,
                       email_df=email_df,
                       category_df=category_df)

c = filter_targeted(classifications_by_week=c,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df,
      ranked=True)
# Out:
# removed 152 rows
# removed:
# Empty DataFrame
# Columns: [panoptes_project_name, iso_week, classifications, categories]
# Index: []
#        classifications_x  classifications_y
# count          85.000000          85.000000
# mean            4.531983           4.762186
# std             3.262657           3.302964
# min             0.000000           0.000000
# 25%             1.791759           2.079442
# 50%             3.871201           3.496508
# 75%             7.380879           7.248504
# max            11.608345          11.683900
# statistic: 1663.0
# p value: 0.5863729482207648)

# %% [markdown]
# # wilcoxon signed-rank test: non-targetted projects & non-targeted topics
# Remove all observations where a project was the target of a newsletter, and all projects that had the a different topic as the project targeted in the newsletter

# %%
c = filter_by_category(classifications_by_week=log_classifications_by_week,
                       email_df=email_df,
                       category_df=category_df,
                       remove_targeted=False)

c = filter_targeted(classifications_by_week=c,
                    email_df=email_df)

ttest(classifications_by_week=c,
      email_df=email_df,
      ranked=True)
# Out:
# removed 202 rows
# removed:
#        panoptes_project_name  iso_week  classifications  \
# 342         camera catalogue    104862         7.901007
# 484   decoding the civil war    104856         2.564949
# 485   decoding the civil war    104857         9.005282
# 867           mapping change    104869         0.000000
# 868           mapping change    104870         8.783549
# 1010        radio meteor zoo    104864        10.458636
# 1219      snapshot wisconsin    104851         9.494842
# 1220      snapshot wisconsin    104852        12.107528
# 1320            snow spotter    104878         3.713572
# 1321            snow spotter    104879        11.025588
#
#                             categories
# 342              {'Biology', 'Nature'}
# 484                        {'History'}
# 485                        {'History'}
# 867   {'Biology', 'Nature', 'Climate'}
# 868   {'Biology', 'Nature', 'Climate'}
# 1010                       {'Physics'}
# ...

# %%
def ttest_viz(classifications_by_week, email_df, window=1):

    '''# group classifications by project and iso_week
    classifications_by_week = classification_df.groupby(['panoptes_project_id','iso_week'])['iso_week'].size()
    # add 0s for missing weeks
    classifications_by_week = classifications_by_week.reindex(pd.MultiIndex.from_product(classifications_by_week.index.levels, names=classifications_by_week.index.names),fill_value=0)
    classifications_by_week = classifications_by_week.to_frame('classification_count').reset_index()'''
    
    # create dfs with start and end iso_weeks
    start = email_df['iso_week'].subtract(window).to_frame('start')
    end = email_df['iso_week'].add(window-1).to_frame('end')
    windowed_classifications_by_week_start = classifications_by_week.loc[(classifications_by_week['iso_week'].isin(start['start']))]
    windowed_classifications_by_week_end = classifications_by_week.loc[(classifications_by_week['iso_week'].isin(end['end']))]
    
    # merge start and end week classification counts into single df
    windowed_classifications_by_week_end = windowed_classifications_by_week_end.rename(columns={'iso_week':'iso_week_y'})
    windowed_classifications_by_week_end['iso_week_x'] = windowed_classifications_by_week_end['iso_week_y'].subtract(1)
    windowed_classifications_by_week_start = windowed_classifications_by_week_start.rename(columns={'iso_week':'iso_week_x'})
    windowed_classifications_by_week = windowed_classifications_by_week_start.merge(windowed_classifications_by_week_end,on=['panoptes_project_name','iso_week_x'])
    
    # only include weeks where there was at least one classification before or after the newsletter
    windowed_classifications_by_week = windowed_classifications_by_week.loc[(windowed_classifications_by_week['classifications_x'] > 0) | (windowed_classifications_by_week['classifications_y'] > 0)]
    for iso_week in windowed_classifications_by_week['iso_week_x'].unique():
        classification_diff = windowed_classifications_by_week.loc[windowed_classifications_by_week['iso_week_x'] == iso_week]
        classification_diff = classification_diff.set_index('panoptes_project_name')[['classifications_x','classifications_y']].transpose()
        classification_diff.plot(figsize = (6,6),
                                 marker='.',
                                 markersize=10)
        
        plt.margins(x=.5)
        plt.use_sticky_edges=False
        plt.show()
        

ttest_viz(classifications_by_week=log_classifications_by_week, email_df=email_df)
