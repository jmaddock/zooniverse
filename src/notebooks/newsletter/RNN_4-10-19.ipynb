# %%
df = read.csv("/srv/zooniverse/pre_regression/4-10-19.csv")
fit <- lm(classifications ~ newsletter + targeted_topic*newsletter + newsletter*targeted + panoptes_project_name + iso_week + rel_week*panoptes_project_name, data=df)
summary(fit)
# Out:
# Call:
# lm(formula = classifications ~ newsletter + targeted_topic *
#     newsletter + newsletter * targeted + panoptes_project_name +
#     iso_week + rel_week * panoptes_project_name, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.8678 -1.0757  0.0406  1.1357  4.9090
#
# Coefficients: (1 not defined because of singularities)
#                                                            Estimate Std. Error
# (Intercept)                                              -1.450e+04  1.542e+03
# newsletter                                               -1.634e+00  1.975e+00
# targeted_topic                                           -2.886e-01  4.049e-01
# targeted                                                 -1.026e+00  6.503e-01
# panoptes_project_nameastronomy rewind                     3.342e+00  1.492e+00
# panoptes_project_namebash the bug                         1.151e+00  1.553e+00
# ...

# %%
df = read.csv("/srv/zooniverse/pre_regression/bandwodth_2_4-10-19.csv")
fit <- lm(classifications ~ newsletter + targeted_topic*newsletter + newsletter*targeted + panoptes_project_name + iso_week + rel_week*panoptes_project_name, data=df)
summary(fit)
# Out:
# Call:
# lm(formula = classifications ~ newsletter + targeted_topic *
#     newsletter + newsletter * targeted + panoptes_project_name +
#     iso_week + rel_week * panoptes_project_name, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.0302 -0.9288 -0.0040  0.9665  4.9907
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                              -1.307e+04  9.123e+02
# newsletter                                               -1.436e-01  3.426e-01
# targeted_topic                                           -3.226e-02  2.328e-01
# targeted                                                 -1.191e+00  4.125e-01
# panoptes_project_nameastronomy rewind                     2.582e+00  5.720e-01
# panoptes_project_namebash the bug                         3.258e-01  5.854e-01
# panoptes_project_namebrain match                          2.109e+00  5.854e-01
# ...

# %%
df = read.csv("/srv/zooniverse/pre_regression/bandwodth_3_4-10-19.csv")
fit <- lm(classifications ~ newsletter + targeted_topic*newsletter + newsletter*targeted + panoptes_project_name + iso_week + rel_week*panoptes_project_name, data=df)
summary(fit)
# Out:
# Call:
# lm(formula = classifications ~ newsletter + targeted_topic *
#     newsletter + newsletter * targeted + panoptes_project_name +
#     iso_week + rel_week * panoptes_project_name, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.1185 -0.8986 -0.0215  1.0215  5.9614
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                              -1.193e+04  7.281e+02
# newsletter                                                1.221e-02  2.641e-01
# targeted_topic                                            4.708e-02  1.873e-01
# targeted                                                 -1.148e+00  3.363e-01
# panoptes_project_nameastronomy rewind                     2.149e+00  4.457e-01
# panoptes_project_namebash the bug                        -6.086e-02  4.558e-01
# panoptes_project_namebrain match                          1.562e+00  4.558e-01
# ...
